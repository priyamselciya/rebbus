# %%
pip install pandas selenium mysql-connector-python sqlalchemy streamlit
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\redbus -REDBUS\02_big_data.csv')

# %%
df.head()
# Out:
#     state                    route  \
# 0  APSRTC  Hyderabad to Vijayawada
# 1  APSRTC  Hyderabad to Vijayawada
# 2  APSRTC  Hyderabad to Vijayawada
# 3  APSRTC  Hyderabad to Vijayawada
# 4  APSRTC  Hyderabad to Vijayawada
#
#                                                 link         busname  \
# 0  https://www.redbus.in/bus-tickets/hyderabad-to...   APSRTC - 3580
# 1  https://www.redbus.in/bus-tickets/hyderabad-to...   APSRTC - 9319
# 2  https://www.redbus.in/bus-tickets/hyderabad-to...   APSRTC - 3576
# 3  https://www.redbus.in/bus-tickets/hyderabad-to...  APSRTC - 35154
# 4  https://www.redbus.in/bus-tickets/hyderabad-to...  APSRTC - 24291
#
#                                       bustype departing_time duration  \
# 0  AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)          12:15  05h 45m
# 1      SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)          13:00  06h 20m
# 2  AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)          13:15  06h 15m
# ...

# %%
df.describe()
# Out:
#              price  star_rating
# count  5524.000000  5524.000000
# mean    622.436197     3.454435
# std     516.711219     0.923192
# min      48.000000     1.000000
# 25%     376.000000     3.000000
# 50%     517.000000     3.500000
# 75%     736.000000     4.100000
# max    8700.000000     5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5524 entries, 0 to 5523
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            5524 non-null   object
#  1   route            5524 non-null   object
#  2   link             5524 non-null   object
#  3   busname          5524 non-null   object
#  4   bustype          5524 non-null   object
#  5   departing_time   5524 non-null   object
#  6   duration         5524 non-null   object
#  7   reaching_time    5524 non-null   object
#  8   price            5524 non-null   float64
#  9   star_rating      5524 non-null   float64
#  10  seats_available  5524 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 474.8+ KB

# %%
df.isnull().sum()
# Out:
# state              0
# route              0
# link               0
# busname            0
# bustype            0
# departing_time     0
# duration           0
# reaching_time      0
# price              0
# star_rating        0
# seats_available    0
# dtype: int64

# %%
df[df.duplicated(keep=False)]
# Out:
#                                 state                    route  \
# 2450  TSRTC Online Bus Ticket Booking  Hyderabad to Sathupally
# 2461  TSRTC Online Bus Ticket Booking  Hyderabad to Sathupally
#
#                                                    link           busname  \
# 2450  https://www.redbus.in/bus-tickets/hyderabad-to...  Mahadevv travels
# 2461  https://www.redbus.in/bus-tickets/hyderabad-to...  Mahadevv travels
#
#                              bustype departing_time duration reaching_time  \
# 2450  Non A/C Seater / Sleeper (2+1)          22:00  05h 30m         03:30
# 2461  Non A/C Seater / Sleeper (2+1)          22:00  05h 30m         03:30
#
#       price  star_rating     seats_available
# 2450  499.0          3.2  31 Seats available
# 2461  499.0          3.2  31 Seats available

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5523 entries, 0 to 5523
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            5523 non-null   object
#  1   route            5523 non-null   object
#  2   link             5523 non-null   object
#  3   busname          5523 non-null   object
#  4   bustype          5523 non-null   object
#  5   departing_time   5523 non-null   object
#  6   duration         5523 non-null   object
#  7   reaching_time    5523 non-null   object
#  8   price            5523 non-null   float64
#  9   star_rating      5523 non-null   float64
#  10  seats_available  5523 non-null   object
# dtypes: float64(2), object(9)
# memory usage: 517.8+ KB

# %%
df.head()
# Out:
#     state                    route  \
# 0  APSRTC  Hyderabad to Vijayawada
# 1  APSRTC  Hyderabad to Vijayawada
# 2  APSRTC  Hyderabad to Vijayawada
# 3  APSRTC  Hyderabad to Vijayawada
# 4  APSRTC  Hyderabad to Vijayawada
#
#                                                 link         busname  \
# 0  https://www.redbus.in/bus-tickets/hyderabad-to...   APSRTC - 3580
# 1  https://www.redbus.in/bus-tickets/hyderabad-to...   APSRTC - 9319
# 2  https://www.redbus.in/bus-tickets/hyderabad-to...   APSRTC - 3576
# 3  https://www.redbus.in/bus-tickets/hyderabad-to...  APSRTC - 35154
# 4  https://www.redbus.in/bus-tickets/hyderabad-to...  APSRTC - 24291
#
#                                       bustype departing_time duration  \
# 0  AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)          12:15  05h 45m
# 1      SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)          13:00  06h 20m
# 2  AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)          13:15  06h 15m
# ...

# %%
df.rename(columns={'seats_available': 'seat_availablity'},inplace=True)

# %%
df.columns
# Out:
# Index(['state', 'route', 'link', 'busname', 'bustype', 'departing_time',
#        'duration', 'reaching_time', 'price', 'star_rating',
#        'seat_availablity'],
#       dtype='object')

# %%
df['seat_availablity'] = df['seat_availablity'].str.extract(r'(\d+)').astype(int)

# %%
df
# Out:
#            state                         route  \
# 0         APSRTC       Hyderabad to Vijayawada
# 1         APSRTC       Hyderabad to Vijayawada
# 2         APSRTC       Hyderabad to Vijayawada
# 3         APSRTC       Hyderabad to Vijayawada
# 4         APSRTC       Hyderabad to Vijayawada
# ...          ...                           ...
# 5519  WBTC (CTC)             Kolkata to Haldia
# 5520  WBTC (CTC)             Kolkata to Haldia
# 5521  WBTC (CTC)  Midnapore to Kolkata Airport
# 5522  WBTC (CTC)  Midnapore to Kolkata Airport
# 5523  WBTC (CTC)  Midnapore to Kolkata Airport
#
#                                                    link  \
# 0     https://www.redbus.in/bus-tickets/hyderabad-to...
# 1     https://www.redbus.in/bus-tickets/hyderabad-to...
# 2     https://www.redbus.in/bus-tickets/hyderabad-to...
# 3     https://www.redbus.in/bus-tickets/hyderabad-to...
# 4     https://www.redbus.in/bus-tickets/hyderabad-to...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5523 entries, 0 to 5523
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   state             5523 non-null   object
#  1   route             5523 non-null   object
#  2   link              5523 non-null   object
#  3   busname           5523 non-null   object
#  4   bustype           5523 non-null   object
#  5   departing_time    5523 non-null   object
#  6   duration          5523 non-null   object
#  7   reaching_time     5523 non-null   object
#  8   price             5523 non-null   float64
#  9   star_rating       5523 non-null   float64
#  10  seat_availablity  5523 non-null   int64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 517.8+ KB

# %%
df.to_csv(r'D:\redbus -REDBUS\03_cleaned_data.csv', index=False)
